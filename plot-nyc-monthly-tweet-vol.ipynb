# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
d = relativedelta(months=1)

# %%
NYC_vol = list([256,317,833,1454,1183,565,961,968,1181,1171,1849,1127,1717,1580,2086,1453,1963,2327,1970,2204,2296,1808,2141,1783,1322,2612,2133,2283,3154,3140,3504,3938,4306,3089,5860,3487,4945,4893,5006,4645,5690,6225,1811,4635,4875,6076,5894,8533,8480,506,7289,7293,5763,4639,1929,5864,7451,7306,7729,8032,9675,9402,1691,247])

# %%
dates = [datetime(2010,3,1)+i*relativedelta(months=1) for i in range(len(NYC_vol))]

# %%
fig = plt.figure(figsize=(20,8))
ax = fig.add_axes([0.2,0.2,0.7,0.7])
ax.plot(dates,NYC_vol,'.-',linewidth=2,markersize=10)
# ax.set_ylim()
# ax.set_xlim()
# ax.legend()
ax.set_xlabel('time',fontsize=15)
ax.set_ylabel('frequency',fontsize=15)
plt.savefig('NYC-monthly.png')
